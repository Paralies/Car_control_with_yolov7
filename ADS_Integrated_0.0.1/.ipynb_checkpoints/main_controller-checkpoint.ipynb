# %%
import import_ipynb
from pid import PID
from Server import *
from imageProcessing import imgProcessing

import cv2
import numpy as np
import math

IP = '127.0.0.1'
CAMERA_PORT = 2210
VEHICLE_INFO_PORT = 50301
LIDAR_PORT = 50001
CONTROL_SIGNAL_PORT = 50302

prev_frame_t = time.time()
p_carData = np.zeros((720, 1280), np.uint8)
    
tcp_camera = CamerReceiver(IP, CAMERA_PORT)
    
udp_vehicleInfo = VehicleInfoReceiver(IP, VEHICLE_INFO_PORT)

udp_lidar = LidarDataReceiver(IP, LIDAR_PORT)
    
udp_controlSignal = ControlSignalSender(IP, CONTROL_SIGNAL_PORT)
    
read_socket_list = [tcp_camera.get_socket(), udp_vehicleInfo.get_socket(), udp_lidar.get_socket()]

img_processor = imgProcessing()

accel_PID = PID(1 / 100, 0.0001, 0.001)
brake_PID = PID(1 / 200, 0.0001, 0.001)
stear_PID = PID(3, 0.01, 0.06)

accel_q = [ 0 for _ in range(640) ]
brake_q = [ 0 for _ in range(640) ]
stear_q = [ 0 for _ in range(640) ]

accel = 0
brake = 1
gear = 0
stear = 0

shouldStop = True
    
while True:
    conn_read_socket_list, conn_write_socket_list, conn_except_socket_list = select.select(read_socket_list, [], [])
    
    #Receive Data(Camera[TCP] / VehicleInfo[UDP] / Lidar[UDP]) with I/O Multiplexing
    for conn_read_socket in conn_read_socket_list:
        if conn_read_socket == tcp_camera.get_socket():
            #RECEIVE CAMERA DATA
            try:
                src, fps = tcp_camera.receive_img()
                font = cv2.FONT_HERSHEY_PLAIN
                text = 'FPS: ' + str(fps)
                cv2.putText(src, text ,(5,15),font, 1, (0,0,0), 2)
                cv2.imshow("Camera", src)
            except Exception as e:
                print(e)
        if conn_read_socket == udp_vehicleInfo.get_socket():
            #RECEIVE Vehicle Info DATA
            try:
                new_frame_t = time.time()
                if new_frame_t - prev_frame_t > 0.2:
                    carData = udp_vehicleInfo.receive_datas()
                    p_carData = udp_vehicleInfo.make_print(carData)
                    prev_frame_t = new_frame_t
                cv2.imshow("CarData", p_carData)
            except Exception as e:  
                print(e)
        if conn_read_socket == udp_lidar.get_socket():
            #Receive Lidar Data
            try:
                lidar_data = 1
            except Exception as e:  
                print(e)
        
    #Calculate Control Signal
    try:
        #HSV transform
        hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)
        #Calculate and draw error
        hud, error = img_processor.draw_error(src, hsv, 300, 200)
        #Show result
        cv2.imshow("HUD", hud)
        if shouldStop != True:
            #Get error
            accel_error, brake_error, stear_error = error 
            #Compute error to PID
            stear_radian = math.atan(stear_error/50)
            stear = stear_PID.computePID(stear_radian)
            accel = accel_PID.computePID(accel_error)
            brake = brake_PID.computePID(brake_error)
            #Put in queue
            accel_q.pop(0)
            brake_q.pop(0)
            stear_q.pop(0)
            accel_q.append(accel)
            brake_q.append(brake)
            stear_q.append(stear * 180 / math.pi)
        #Draw Monitor of each control signal 
        accel_monitor = img_processor.draw_monitor(accel_q)
        cv2.imshow("Accel", accel_monitor)
        brake_monitor = img_processor.draw_monitor(brake_q)
        cv2.imshow("Brake", brake_monitor)
        stear_monitor = img_processor.draw_monitor(stear_q)
        cv2.imshow("Stear", stear_monitor)
    except Exception as e:  
        print(e)
        
    #Send Control Singnal
    try:
        udp_controlSignal.sendSignal(accel, brake, gear, stear)
        monitor = udp_controlSignal.make_print(accel, brake, gear, stear)
        cv2.imshow("ControlSignal", monitor)
    except Exception as e:
        print(e)
        break
        
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
    if cv2.waitKey(1) & 0xFF == ord('s'):
        gear = 1
        shouldStop = False
            
cv2.destroyAllWindows()

tcp_camera.quit_receive()
udp_vehicleInfo.quit_receive()
udp_lidar.quit_receive()
udp_controlSignal.quit_receive()
# Out:
# importing Jupyter notebook from pid.ipynb
# importing Jupyter notebook from Server.ipynb
# importing Jupyter notebook from imageProcessing.ipynb
# TCP Socket Connected[ 127.0.0.1 2210 ]
# *IPGMovie 11.1 2022-10-19
#
# *RSDS 0 rgb 0.060 640x480 921600
# Detected WIDTH: 640 Detected HEIGHT: 480
# UDP Socket Connected[ 127.0.0.1 50301 ]
# UDP Socket Connected[ 127.0.0.1 50001 ]
# UDP Socket Connected[ 127.0.0.1 50302 ]
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# ...
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
#
# QObject::moveToThread: Current thread (0x12f68f0) is not the object's thread (0x1b366a0).
# Cannot move to target thread (0x12f68f0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 54
#      51 if conn_read_socket == tcp_camera.get_socket():
#      52     #RECEIVE CAMERA DATA
#      53     try:
# ---> 54         src, fps = tcp_camera.receive_img()
#      55         font = cv2.FONT_HERSHEY_PLAIN
#      56         text = 'FPS: ' + str(fps)
#
# File <string>:97, in receive_img(self)
#
# File <string>:83, in receive_datas(self)
#
# File <string>:30, in recvall(self, count)
#
# KeyboardInterrupt:

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
# !pip install import_ipynb
# Out:
# Collecting import_ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from import_ipynb) (8.7.0)
# Requirement already satisfied: nbformat in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from import_ipynb) (5.7.0)
# Requirement already satisfied: pickleshare in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: stack-data in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (4.8.0)
# Requirement already satisfied: decorator in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (3.0.36)
# Requirement already satisfied: backcall in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: fastjsonschema in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from nbformat->import_ipynb) (2.16.2)
# Requirement already satisfied: jupyter-core in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from nbformat->import_ipynb) (5.1.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from nbformat->import_ipynb) (4.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from jedi>=0.16->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (22.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from pexpect>4.3->IPython->import_ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from jupyter-core->nbformat->import_ipynb) (2.5.2)
# Requirement already satisfied: executing in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from stack-data->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: pure-eval in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from stack-data->IPython->import_ipynb) (0.2.2)
# Requirement already satisfied: asttokens in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from stack-data->IPython->import_ipynb) (2.0.5)
# Requirement already satisfied: six in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from asttokens->stack-data->IPython->import_ipynb) (1.16.0)
# Installing collected packages: import_ipynb
# Successfully installed import_ipynb-0.1.4

# %%
# !pip install --no-binary opencv-python opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.17.3 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from opencv-python) (1.24.1)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/gyoominlee/anaconda3/envs/hyundai/bin/python -m pip install --upgrade pip' command.

# %%
# !pip uninstall opencv-python
# Out:
# Found existing installation: opencv-python 4.7.0.68
# Uninstalling opencv-python-4.7.0.68:
#   Would remove:
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/cv2/*
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python-4.7.0.68.dist-info/*
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libQt5Core-b6e66ee2.so.5.15.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libQt5Gui-dd62182f.so.5.15.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libQt5Test-c38a5234.so.5.15.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libQt5Widgets-e69d94fb.so.5.15.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libQt5XcbQpa-dcb826d0.so.5.15.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libX11-xcb-69166bdf.so.1.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libXau-00ec42fe.so.6.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libavcodec-087c3416.so.59.37.100
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libavformat-85e01647.so.59.27.100
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libavutil-82c407cb.so.57.28.100
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libcrypto-9cee340d.so.1.1
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libgfortran-91cc3cb1.so.3.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libopenblas-r0-f650aae0.3.3.so
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libpng16-186fce2e.so.16.37.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libquadmath-96973f99.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libssl-16e42f2f.so.1.1
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libswresample-d02fa90a.so.4.7.100
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libswscale-9b504c0d.so.6.7.100
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libvpx-5d0a9e1a.so.7.1.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-icccm-413c9f41.so.4.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-image-e82a276d.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-keysyms-21015570.so.1.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-randr-a96a5a87.so.0.1.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-render-637b984a.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-render-util-43ce00f5.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-shape-25c2b258.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-shm-7a199f70.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-sync-89374f40.so.1.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-util-4d666913.so.1.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-xfixes-9be3ba6f.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-xinerama-ae147f87.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxcb-xkb-9ba31ab3.so.1.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxkbcommon-71ae2972.so.0.0.0
#     /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages/opencv_python.libs/libxkbcommon-x11-c65ed502.so.0.0.0
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %%
# !pip install opencv-python-headless
# Out:
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
# Requirement already satisfied: numpy>=1.21.2 in /home/gyoominlee/anaconda3/envs/hyundai/lib/python3.10/site-packages (from opencv-python-headless) (1.24.1)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.7.0.68
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/gyoominlee/anaconda3/envs/hyundai/bin/python -m pip install --upgrade pip' command.

# %%
# !pkg-config --modversion opencv
# Out:
# Package opencv was not found in the pkg-config search path.
# Perhaps you should add the directory containing `opencv.pc'
# to the PKG_CONFIG_PATH environment variable
# No package 'opencv' found
